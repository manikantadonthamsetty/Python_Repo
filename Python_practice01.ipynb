# %% [markdown]
# <a href="https://colab.research.google.com/github/manikantadonthamsetty/Python_Repo/blob/main/Python_practice01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('manid python code')
print(3+6)
# Out:
# manid python code
# 9
